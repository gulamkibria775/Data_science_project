# %% [markdown]
# <a href="https://colab.research.google.com/github/gulamkibria775/Data_science_project/blob/main/Data_science_project%20/Deep_learning/single_image_data_augumentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/driver')
# Out:
# Drive already mounted at /content/driver; to attempt to forcibly remount, call drive.mount("/content/driver", force_remount=True).

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
img=image.load_img('/content/driver/MyDrive/All_data_file/HD-wallpaper-sweet-cat.jpg',target_size=(300,300))

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    shear_range=.2,
    zoom_range=.2,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=.2,
    height_shift_range=.2,
    fill_mode='constant'
)

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (300, 300, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
input_batch=img.reshape(1,300,300,3)

# %%
i=0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='/content/driver/MyDrive/All_data_file/aug'):
  i=i+1
  if i==10:
    break
